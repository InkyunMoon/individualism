# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

plt.rcParams["figure.figsize"] = (15,15)

# %%
gpd.__version__
# Out:
# '0.6.1'

# %%
countries = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

countries.tail(3)
# Out:
#       pop_est      continent                 name iso_a3  gdp_md_est  \
# 174   1895250         Europe               Kosovo    -99     18490.0
# 175   1218208  North America  Trinidad and Tobago    TTO     43570.0
# 176  13026129         Africa             S. Sudan    SSD     20880.0
#
#                                               geometry
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...

# %%
cities.tail()
# Out:
#           name                     geometry
# 197      Cairo    POINT (31.24802 30.05191)
# 198      Tokyo   POINT (139.74946 35.68696)
# 199      Paris     POINT (2.33139 48.86864)
# 200   Santiago  POINT (-70.66899 -33.44807)
# 201  Singapore    POINT (103.85387 1.29498)

# %%
ax = countries.plot(column = 'continent', legend = True, categorical = True)
ax.set_title('세계 지도')
ax.set_axis_off()
plt.show()
# Out:
# C:\Users\moon\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\moon\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 1인당 GDP 연산
countries['gdp_per_cap'] = countries['gdp_md_est'] / countries['pop_est'] * 100

ax = countries.plot(column='gdp_per_cap', legend=True, scheme='quantiles', cmap="Blues", k=5)
ax.set_axis_off()
ax.set_title("세계 국가의 1인당 GDP")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\geopandas\plotting.py in _mapclassify_choro(values, scheme, **classification_kwds)
#     658     try:
# --> 659         import mapclassify.classifiers as classifiers
#     660     except ImportError:
#
# ModuleNotFoundError: No module named 'mapclassify'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\geopandas\plotting.py in _mapclassify_choro(values, scheme, **classification_kwds)
#     661         try:
# --> 662             import pysal.viz.mapclassify.classifiers as classifiers
#     663         except ImportError:
#
# ModuleNotFoundError: No module named 'pysal'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
gym = gpd.read_file('C:\\Users\\moon\\Desktop\\추가 반출\\441. 서울시 공공체육시설 공간데이터\\2. 파일데이터\\2017\\공공체육시설\\TL_PUB_ALSFC\\TL_PUB_ALSFC.shp', encoding='cp949')

# %%
gym.head()
# Out:
#    ALSFC_ID    ALSFC_KEY  ALSFC_NM                            ADRES  OLD_ZIP  \
# 0        90  YC10078PUMU  계남다목적체육관              서울특별시 양천구 신정로 273-5  158-070
# 1        91  YC10079PUMU  목동문화체육센터              서울특별시 양천구 목동중앙본로 73  158-052
# 2        92  YC10080PUMU  신월문화체육센터       서울특별시 양천구 지양길 47(신월7동 987)  158-097
# 3        93  YC10081PUMU  양천구민체육센터  서울특별시 양천구 목동 동로 57 (신정동 322-10)  158-070
# 4        94  YC10082PUMU  양천주민편익시설              서울특별시 양천구 안양천로 1121  158-872
#
#                                                 HMPG EMAIL           TELNO  \
# 0  http://www.ycs.or.kr/parking/gyenam_introducti...  None    02-2605-9301
# 1  http://www.ycs.or.kr/rent/mokdong_introduction...  None  02-2062-1862~4
# 2  http://www.ycs.or.kr/rent/swec_introduction02.php  None  02-2605-4093~5
# 3  http://www.ycs.or.kr/rent/ycec_introduction02.php  None    02-2652-1792
# 4  http://www.ycymca.or.kr/one_html/index.php?men...  None    02-2652-8083
#
# ...

# %%
gym_short = gym[['ALSFC_NM','ADRES','POSESN_ORG','geometry']]
gym_short
# Out:
#       ALSFC_NM                            ADRES POSESN_ORG  \
# 0     계남다목적체육관              서울특별시 양천구 신정로 273-5        양천구
# 1     목동문화체육센터              서울특별시 양천구 목동중앙본로 73        양천구
# 2     신월문화체육센터       서울특별시 양천구 지양길 47(신월7동 987)        양천구
# 3     양천구민체육센터  서울특별시 양천구 목동 동로 57 (신정동 322-10)        양천구
# 4     양천주민편익시설              서울특별시 양천구 안양천로 1121        서울시
# ..         ...                              ...        ...
# 424  망원유수지체육공원             서울특별시 마포구 망원2동 450-3       마포구청
# 425  방배배수지체육공원               서울특별시 서초구 방배3동 599        서초구
# 426    중랑물재생센터               서울특별시 성동구 차장터5길 10        서울시
# 427      가좌배수지          서울특별시 서대문구 홍은2동 산26-170       서대문구
# 428      홍은배수지           서울특별시 서대문구 홍은1동 산1-551       서대문구
#
#                           geometry
# 0    POINT (186779.781 545966.230)
# 1    POINT (188375.542 549285.269)
# 2    POINT (185403.916 546708.708)
# 3    POINT (188026.003 546328.493)
# 4    POINT (189731.520 549104.681)
# ..                             ...
# ...

# %%
gym_short
# Out:
#       ALSFC_NM                            ADRES POSESN_ORG  \
# 0     계남다목적체육관              서울특별시 양천구 신정로 273-5        양천구
# 1     목동문화체육센터              서울특별시 양천구 목동중앙본로 73        양천구
# 2     신월문화체육센터       서울특별시 양천구 지양길 47(신월7동 987)        양천구
# 3     양천구민체육센터  서울특별시 양천구 목동 동로 57 (신정동 322-10)        양천구
# 4     양천주민편익시설              서울특별시 양천구 안양천로 1121        서울시
# ..         ...                              ...        ...
# 424  망원유수지체육공원             서울특별시 마포구 망원2동 450-3       마포구청
# 425  방배배수지체육공원               서울특별시 서초구 방배3동 599        서초구
# 426    중랑물재생센터               서울특별시 성동구 차장터5길 10        서울시
# 427      가좌배수지          서울특별시 서대문구 홍은2동 산26-170       서대문구
# 428      홍은배수지           서울특별시 서대문구 홍은1동 산1-551       서대문구
#
#                           geometry
# 0    POINT (186779.781 545966.230)
# 1    POINT (188375.542 549285.269)
# 2    POINT (185403.916 546708.708)
# 3    POINT (188026.003 546328.493)
# 4    POINT (189731.520 549104.681)
# ..                             ...
# ...

# %%
df_count = gym_short.groupby(by='POSESN_ORG').count().iloc[:,0].to_frame()

# %%
df_count
# Out:
#             ALSFC_NM
# POSESN_ORG
# 강남구               13
# 강동구               11
# 강북구                9
# 강서구               17
# 관악구               10
# 광진구                8
# 교육청(학교)           59
# 구로구                6
# 구립                 3
# 국민체육진흥공단           1
# 금천구                6
# 노원구               16
# 대한체육회              1
# 도봉구                7
# 동대문구               5
# 동작구               10
# 동작구 시설관리공단         1
# 마포구                7
# 마포구청               1
# 서대문구               8
# 서울시               93
# 서초구               16
# 성동구                7
# 성북구               12
# 송파구               16
# 시립                 4
# 양천구               13
# 영등포구               8
# 용산구               14
# 은평구                5
# 종로구                7
# 중구                10
# 중랑구               11
# 한국철도시설공단           1

# %%
# gym2 = gym.to_crs(epsg=3857)
gym_short.plot(color='gray')

# %%
gym_gn = gym_short[gym_short['POSESN_ORG'] == '강남구']

# %%
gym_gn.plot()

# %%
seoul = gpd.read_file('C:\\Users\\moon\\Desktop\\LSMD_ADM_SECT_UMD_서울\\LSMD_ADM_SECT_UMD_11.shp', encoding='cp949')

# %%
seoul.plot(color='gray')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline
# mpl.rc('font', family='malgun.ttf') #한글 폰트 적용시
plt.rcParams["figure.figsize"] = (20,10) #차트 사이즈

# chropleth map
fig, ax = plt.subplots(1,1)
# legend
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
# visualization

column = ''
gym_gn.plot(column, ax = ax, legend = True, cax = cax, cmap='OrRd')

ax.set_title('temp')
ax.set_axis_off()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-feaa8785936f> in <module>
#      15
#      16 column = ''
# ...
