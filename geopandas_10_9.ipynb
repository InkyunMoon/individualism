# %% [markdown]
# ### geopandas & descartes 라이브러리 설치 필요

# %%
import pandas as pd
import numpy as np

import geopandas as gpd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ### gpd.read_file로 shp파일을 읽어온다.
# - shp파일만 있으면 오류가 발생한다. dbf, shx 파일도 함께 있어야 한다.

# %%
gym = gpd.read_file('C:\\Users\\moon\\Desktop\\추가 반출\\441. 서울시 공공체육시설 공간데이터\\2. 파일데이터\\2017\\공공체육시설\\TL_PUB_ALSFC\\TL_PUB_ALSFC.shp', encoding='cp949')

# %%
gym
# Out:
#      ALSFC_ID    ALSFC_KEY   ALSFC_NM                            ADRES  \
# 0          90  YC10078PUMU   계남다목적체육관              서울특별시 양천구 신정로 273-5
# 1          91  YC10079PUMU   목동문화체육센터              서울특별시 양천구 목동중앙본로 73
# 2          92  YC10080PUMU   신월문화체육센터       서울특별시 양천구 지양길 47(신월7동 987)
# 3          93  YC10081PUMU   양천구민체육센터  서울특별시 양천구 목동 동로 57 (신정동 322-10)
# 4          94  YC10082PUMU   양천주민편익시설              서울특별시 양천구 안양천로 1121
# ..        ...          ...        ...                              ...
# 424       426  MP10581QURF  망원유수지체육공원             서울특별시 마포구 망원2동 450-3
# 425       427  SC10582QURF  방배배수지체육공원               서울특별시 서초구 방배3동 599
# 426       428  SD10583QURF    중랑물재생센터               서울특별시 성동구 차장터5길 10
# 427       429  SM10584QUEF      가좌배수지          서울특별시 서대문구 홍은2동 산26-170
# 428       430  SM10585QURF      홍은배수지           서울특별시 서대문구 홍은1동 산1-551
#
#       OLD_ZIP                                               HMPG EMAIL  \
# ...

# %%
seoul = gpd.read_file('C:\\Users\\moon\\Desktop\\LSMD_ADM_SECT_UMD_서울\\LSMD_ADM_SECT_UMD_11.shp', encoding='cp949')

ax = seoul.convex_hull.plot(color='grey', edgecolor='w')
ax.set_title('서울')
ax.set_axis_off()
ax2 = gym.convex_hull.plot(color='green', edgecolor='w')
plt.show()

# %%
plt.show()
