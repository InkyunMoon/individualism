# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gym = gpd.read_file('C:\\Users\\moon\\Desktop\\추가 반출\\441. 서울시 공공체육시설 공간데이터\\2. 파일데이터\\2017\공공체육시설\\TL_PUB_ALSFC\\TL_PUB_ALSFC.shp', encoding='cp949')

# %%
gym = gym.to_crs(3857)

# %%
seoul = gpd.read_file('C:\\Users\\moon\\Desktop\\LSMD_ADM_SECT_UMD_서울\\LSMD_ADM_SECT_UMD_11.shp', encoding='cp949')
seoul2 = gpd.read_file('C:\\Users\\moon\\Desktop\\201912기초구역DB_전체분\\서울특별시\\TL_KODIS_BAS_11.shp', encoding='cp949')

# %%
seoul.crs
# Out:
# 3857

# %%
seoul = seoul.to_crs(3857)
# Out:
# C:\Users\moon\anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
seoul
# Out:
#        EMD_CD  EMD_NM  SGG_OID COL_ADM_SE   GID  \
# 0    11440124     연남동     4579      11440  5134
# 1    11440121     동교동     4899      11440  5145
# 2    11290104  동소문동1가     1105      11290  2809
# 3    11290123   안암동3가      406      11290  2810
# 4    11590103    상도1동      385      11590  2665
# ..        ...     ...      ...        ...   ...
# 462  11110112     체부동      323      11110  3035
# 463  11440102     공덕동     5217      11440  5227
# 464  11440109     염리동     5218      11440  5228
# 465  11290133     정릉동     1409      11290  5266
# 466  11290134     길음동     1410      11290  5267
#
#                                               geometry
# 0    POLYGON ((14128271.975 4518393.051, 14128297.0...
# 1    MULTIPOLYGON (((14128534.146 4517106.531, 1412...
# 2    POLYGON ((14138153.896 4521596.398, 14138159.8...
# 3    POLYGON ((14140339.200 4521143.782, 14140327.5...
# 4    POLYGON ((14131583.003 4509481.081, 14131596.3...
# ...

# %%
base = seoul.plot(figsize=(15,15), color = 'w', edgecolor = 'grey')

ax = gym.plot(figsize=(15,15), ax = base, color = 'k', edgecolor = 'k', lw=1)
ax.set_axis_off()
plt.show()

# %% [markdown]
# seoul

# %%
seoul
# Out:
#        EMD_CD  EMD_NM  SGG_OID COL_ADM_SE   GID  \
# 0    11440124     연남동     4579      11440  5134
# 1    11440121     동교동     4899      11440  5145
# 2    11290104  동소문동1가     1105      11290  2809
# 3    11290123   안암동3가      406      11290  2810
# 4    11590103    상도1동      385      11590  2665
# ..        ...     ...      ...        ...   ...
# 462  11110112     체부동      323      11110  3035
# 463  11440102     공덕동     5217      11440  5227
# 464  11440109     염리동     5218      11440  5228
# 465  11290133     정릉동     1409      11290  5266
# 466  11290134     길음동     1410      11290  5267
#
#                                               geometry
# 0    POLYGON ((14128271.975 4518393.051, 14128297.0...
# 1    MULTIPOLYGON (((14128534.146 4517106.531, 1412...
# 2    POLYGON ((14138153.896 4521596.398, 14138159.8...
# 3    POLYGON ((14140339.200 4521143.782, 14140327.5...
# 4    POLYGON ((14131583.003 4509481.081, 14131596.3...
# ...

# %%
seoul2
# Out:
#       BAS_MGT_SN CTP_KOR_NM SIG_CD SIG_KOR_NM BAS_ID  BAS_AR   NTFC_DE  \
# 0     1150000111      서울특별시  11500        강서구  07512   0.060  20121221
# 1     1150000112      서울특별시  11500        강서구  07513   0.046  20121221
# 2     1150000113      서울특별시  11500        강서구  07510   0.101  20121221
# 3     1150000114      서울특별시  11500        강서구  07509   0.064  20121221
# 4     1150000115      서울특별시  11500        강서구  07520   2.452  20121221
# ...          ...        ...    ...        ...    ...     ...       ...
# 5660  1129000011      서울특별시  11290        성북구  02797   0.112  20121221
# 5661  1129000028      서울특별시  11290        성북구  02709   0.150  20121221
# 5662  1129000046      서울특별시  11290        성북구  02851   0.052  20121221
# 5663  1129000047      서울특별시  11290        성북구  02822   1.087  20121221
# 5664  1129000068      서울특별시  11290        성북구  02838   0.126  20121221
#
#        MVMN_DE    MVMN_RESN        OPERT_DE  \
# 0     20121221  국가기초구역 최초생성  20121221000000
# ...
